# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
f = pd.read_csv('ecg.csv')
f
# Out:
#          t  ecg
# 0        0  -33
# 1        1  -31
# 2        2  -39
# 3        3  -41
# 4        4  -37
# ...    ...  ...
# 1275  1275  -23
# 1276  1276  -27
# 1277  1277  -31
# 1278  1278  -31
# 1279  1279  -33
#
# [1280 rows x 2 columns]

# %%
plt.figure(figsize=(16, 8))
plt.plot(f['ecg'], linewidth = 1)
plt.show()

# %%
n = len(f)
mu = f['ecg'].mean()
d = ((f['ecg'] - mu)**2).sum() / n

# %%
r = []
for k in range(n):
	l = 1.0 / ((n - k) * d)
	sum = 0.0
	for j in range(n - k):
		sum = sum + (f['ecg'][j + k] - mu) * (f['ecg'][j] - mu)
	r.append(l * sum)

# %%
plt.figure(figsize=(16, 8))
plt.plot(r, linewidth = 1)
plt.show()
